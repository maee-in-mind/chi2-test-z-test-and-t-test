# %% [markdown]
# # chi2-test , z-test and t-test

# %%
#chi2-test used when data is in categorical form
# z-test , student t-test used when data is in continuous form

# %%
#used in Decision tree regressor

# %% [markdown]
# #### When to use..

# %%
##1) When features is Categorical and Continuous
##2) Required Large Dataset
##3) NO Significant Outliers

#**** very important note: 
#we separate the continuous and categorical variables 
#1) for continuous we checked correlation with o/p
#2) for categorical features we use SelectKBesst method for selecting best feature among
#   them for that we used chi2 test.

# %% [markdown]
# ![chi_squared_test.svg](attachment:chi_squared_test.svg)

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
x_new=SelectKBest(chi2,k=10).fit_tranform(x,y)
(got reduced features which are important)

# %%
#z-test: when sample size is more than 30
#student t-test: when sample size is less than 30

# %%
#z-test

# %% [markdown]
# ![z_test.svg](attachment:z_test.svg)

# %%
Where--
Z	=	Z-test
x	=	sample average
u	=	mean
s	=	standard deviation

# %%
#student T-Test

# %% [markdown]
# ![student_s_t_test.svg](attachment:student_s_t_test.svg)

# %%
t	=	Student's t-test
m	=	mean
u	=	theoretical value
s	=	standard deviation
n	=	variable set size
